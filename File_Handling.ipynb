# %% [markdown]
# **File_Handling** -> doing work on files.
#
# File :- file is the place where we have the data.

# %% [markdown]
# *The purpopse of file handling
#
# work with the files ex:-> create a file and insert data or read data from the file
#
# * w -> write
# * r -> read
# * a -> add

# %% [markdown]
# **w - Mode**
#
# * 1. If the file is not there in the specific location mode w will create the file and will write the data into the file
# * 2. If the file is there  and there is no data in the file means w will write the data into the file
# * 3. If the file is there and there is data in the file means -> it will override the data

# %%
a = open('syamu.txt','w') # w is created file and open the file

a.write('I am from India')
a.close()

# %%
a = open('prasad.txt','w') # w is created file and open the file

a.write('I am from USA')
a.close()

# %%
a = open('vasu.txt','w') # w is created file and open the file


a.write('Hyderabad')
a.close()

# %% [markdown]
# **a - Mode**
#
# * 1. If the file is not there in the specific location mode a will create the file and will add the data into the file
# * 2. If the file is there  and there is no data in the file means a will add the data into the file
# * 3. If the file is there and there is data in the file means -> it will override the data

# %%
a = open('syamu.txt','a') # w is created file and open the file

a.write('I am from India')
a.close()

# %%
a = open('prasad.txt','a') # w is created file and open the file

a.write('I am from USA')
a.close()

# %%
a = open('vasu.txt','a') # w is created file and open the file


a.write('Hyderabad')
a.close()

# %% [markdown]
# **r - Mode**
#
# If the file is not there means it is not possible to read the data because file is not there
#  * read -> will read the data exactly how it is in the file
#  * readline -> read only few lines from the file
#  * readlines -> read all the data from the file but in a list manner

# %%
a = open('vasu.txt','r')
print(a.read())
a.close()
# Out:
# Easy to use and Read - Python's syntax is clear and easy to read, making it an ideal language for both beginners and experienced programmers. This simplicity can lead to faster development and reduce the chances of errors.
# Dynamically Typed - The data types of variables are determined during run-time. We do not need to specify the data type of a variable during writing codes.
# High-level - High-level language means human readable code.
# Compiled and Interpreted - Python code first gets compiled into bytecode, and then interpreted line by line. When we download the Python in our system form org we download the default implement of Python known as CPython. CPython is considered to be Complied and Interpreted both.
# Garbage Collected - Memory allocation and de-allocation are automatically managed. Programmers do not specifically need to manage the memory.

# %%
a = open('vasu.txt','r')
print(a.read())
a.close()
# Out:
# Easy to use and Read - Python's syntax is clear and easy to read, making it an ideal language for both beginners and experienced programmers. This simplicity can lead to faster development and reduce the chances of errors.
# Dynamically Typed - The data types of variables are determined during run-time. We do not need to specify the data type of a variable during writing codes.
# High-level - High-level language means human readable code.
# Compiled and Interpreted - Python code first gets compiled into bytecode, and then interpreted line by line. When we download the Python in our system form org we download the default implement of Python known as CPython. CPython is considered to be Complied and Interpreted both.
# Garbage Collected - Memory allocation and de-allocation are automatically managed. Programmers do not specifically need to manage the memory.

# %%
a = open('vasu.txt','r')
print(a.readline())
a.close()
# Out:
# Easy to use and Read - Python's syntax is clear and easy to read, making it an ideal language for both beginners and experienced programmers. This simplicity can lead to faster development and reduce the chances of errors.

# %%
a = open('vasu.txt','r')
print(a.readlines())
a.close()
# Out:
# ["Easy to use and Read - Python's syntax is clear and easy to read, making it an ideal language for both beginners and experienced programmers. This simplicity can lead to faster development and reduce the chances of errors.\n", 'Dynamically Typed - The data types of variables are determined during run-time. We do not need to specify the data type of a variable during writing codes.\n', 'High-level - High-level language means human readable code.\n', 'Compiled and Interpreted - Python code first gets compiled into bytecode, and then interpreted line by line. When we download the Python in our system form org we download the default implement of Python known as CPython. CPython is considered to be Complied and Interpreted both.\n', 'Garbage Collected - Memory allocation and de-allocation are automatically managed. Programmers do not specifically need to manage the memory.\n', '\n']

# %%
# why to close the file

a = open('vasu.txt','w')
a.write('I am from India')
# Out:
# 15

# %%
# file handling in real time code

with open('vasu.txt','w') as a:
  a.write('I am from India')

# %%
with open('vasu.txt','r') as a:
  print(a.read())
# Out:
# I am from India
